# %% [markdown]
# <font color=#1DA1F2>
#
# - **Batch Geocoding:** Nominatim (OpenStreetMap) does not natively support batch geocoding through a single API request. Each geocoding request must be made individually. If you need to perform batch geocoding, you would typically need to loop through multiple requests programmatically, adhering to the service's rate limits.
# - **Rate Limits:**
# The public Nominatim service has a rate limit of 1 request per second (or 3600 requests per hour) per IP address. This limit can vary if you're using a self-hosted instance or a paid service that offers higher limits

# %%
# import libraries
import pandas as pd
from geopy.geocoders import Nominatim 
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
import time
from tqdm import tqdm

# Load the CSV file into a DataFrame
df = pd.read_csv('data/npidata_pfile.csv')

# Extract the first 5 digits of the zip code ,ensure that the zip code is an integer
df['Zip Code'] = df['Zip Code'].apply(lambda x: int(x / 10**(len(str(int(x))) - 5)) if not pd.isna(x) else x).astype('Int64')
# combine the names provider to create a full name column, ensure that the names are strings and it should be last name, first name middle name format 
df['Full Name'] = df['Provider Last Name'] + ', ' + df['Provider First Name'] + ' ' + df['Provider Middle Name']

df=df[['NPI','Full Name','Street','City','State','Zip Code']]
# drop rows with missing values of street 1,full name
df = df.dropna(subset=['Street','Full Name'])
# drop duplicates
df = df.drop_duplicates()
# print(df.shape)
# randomly sample 1000 rows
df = df.sample(1000)
df.sample(15)
# Out:
#               NPI                    Full Name  \
# 26181  1104559293  SARRAZOLLA, SERRIA KATHLEEN
# 4349   1194216952            MURPHY, CAMERON S
# 26278  1073177341          STEWART, NICOLE ANN
# 7030   1699506436   BOGLE, ELIZABETH SHELDRICK
# 3235   1205135522        ODELL, ELIZABETH PHAM
# 50     1558192690  HOLLENBACH, DENISE MICHELLE
# 28147  1639269848         ALBERTSON, JENNIE H.
# 3649   1447089347          LEFEBVRE, HEATHER L
# 2268   1417788456       TORRENTES, RANDY DAVID
# 28829  1902868789  PARAS, RODERICK ROPHEO LAZO
# 14263  1518158112          FULLER, JULIE MARIE
# 13691  1962182071      POWER, PHOEBE CHARLOTTE
# 26125  1972567055             LEE, ANTHONY YUN
# 3280   1568134336        GILHOOLY, RORY THOMAS
# 12740  1295228690             WYCHE, KAITLYN E
#
#                                Street         City State  Zip Code
# 26181             7210 W BARRISTER DR        BOISE    ID     83704
# 4349    20041 RIVERSIDE COMMONS PLAZA      ASHBURN    VA     20147
# 26278                 701 HEWITT BLVD     RED WING    MN     55066
# 7030    4960 CORPORATE DR NW STE 135H   HUNTSVILLE    AL     35805
# 3235             2778 TEAYS VALLEY RD    HURRICANE    WV     25526
# 50                400 TUSCARAWAS ST W       CANTON    OH     44702
# 28147                  20 BRIMBAL AVE      BEVERLY    MA     19151
# 3649   301 MALLORY STATION RD STE 110     FRANKLIN    TN     37067
# 2268          1191 CENTRAL BLVD STE A    BRENTWOOD    CA     94513
# 28829         44151 15TH ST W STE 101    LANCASTER    CA     93534
# 14263        1935 MEDICAL DISTRICT DR       DALLAS    TX     75235
# 13691    450 BROOKLINE AVE # DANA3154       BOSTON    MA     22155
# 26125                700 CHILDRENS DR     COLUMBUS    OH     43205
# 3280           1303 S LINDEN RD STE D        FLINT    MI     48532
# 12740             701 PRAIRIE HAWK DR  CASTLE ROCK    CO     80109

# %%
# Initialize the geolocator
geolocator = Nominatim(user_agent="my_app")

# Function to get latitude and longitude with error handling and retries
def get_lat_long(address, max_retries=3):
    for attempt in range(max_retries):
        try:
            location = geolocator.geocode(address)
            if location:
                return location.latitude, location.longitude
            else:
                return None, None
        except (GeocoderTimedOut, GeocoderServiceError):
            if attempt < max_retries - 1:
                time.sleep(1)  # Wait for 1 second before retrying
            else:
                return None, None
        except Exception:
            return None, None

# Create new column for Clean_address
df['Clean_address'] = df.apply(lambda row: f"{row['Street']}, {row['City']}, {row['State']} {row['Zip Code']} ", axis=1)

# Batch processing function
def process_batch(batch):
    results = []
    for address in batch:
        lat, lon = get_lat_long(address)
        results.append((lat, lon))
        time.sleep(1)  # 1 second delay between each request
    return results

# Set batch size and calculate number of batches
batch_size = 10
num_batches = len(df) // batch_size + (1 if len(df) % batch_size != 0 else 0)

# Process batches
all_results = []
for i in tqdm(range(num_batches), desc="Processing batches"):
    start_idx = i * batch_size
    end_idx = min((i + 1) * batch_size, len(df))
    batch = df['Clean_address'][start_idx:end_idx]
    batch_results = process_batch(batch)
    all_results.extend(batch_results)
    time.sleep(2)  # 2 seconds delay between batches

# Add results to DataFrame
df['latitude'], df['longitude'] = zip(*all_results)

# Save the updated DataFrame to a new CSV file
df.to_csv('data/npidata_pfile_OpenStreetMap_with_coordinates.csv', index=False)
df.sample(25)
# Out:
# Processing batches: 100%|██████████| 100/100 [38:55<00:00, 23.36s/it]
#               NPI                    Full Name  \
# 8348   1699361147            ATLAS, SARAH ROSE
# 373    1558192633              TAYLOR, DIANE P
# 24131  1790759595       REYES, JOAQUIN ALBERTO
# 981    1184455180     BARBERA, CHRISTY STARNA-
# 15330  1235961764   STANISLAUS, JATIERA SHERAY
# 17625  1194186668     CHUKWUTO, FIDELIA CHINWE
# 1883   1578394086     ROSALES CRUZ, LIZ MARIAM
# 3046   1902011588         BURKE, MICHAEL SCOTT
# 15311  1528898681          LUNDIE, BROOKE ANNA
# 1170   1205896131              WHITE, GEORGE F
# 2186   1891543096     PETERS, MORGAN ELIZABETH
# 10140  1518798164         GARZA, LETICIA MARIE
# 19742  1932336203  EBERTOWSKI, JAMES SYLVESTER
# 2423   1508444845          ST MARTIN, AMANDA M
# 5626   1669013744      CADENA, MARISSA LISETTE
# 24908  1306376983       WIPPEL, BRITTANY MARIE
# 18424  1306863006      TARWATER, KRISTEN DEANE
# 21223  1548513997    ANGELES, MARYANNE MANETTA
# 28734  1699074682            GIBSON, BARTLEY D
# 23931  1578274064            WESTON, JAMIE LEE
# 6574   1063162683       ESPY, TOMMIE GABRIELLE
# 6493   1811411754       TERRELL, DAVID CHARLES
# 18629  1083203566     ABRAHAM, WENDY CHRISTINE
# 10661  1033747845         PALMER, NICOLE MARIE
# 27277  1134156383        VANHEUVEN, WICHARD AJ
#
#                                      Street                    City State  \
# 8348          7670 W LAKE MEAD BLVD STE 135               LAS VEGAS    NV
# 373                 2620 BARDSTOWN RD STE 4              LOUISVILLE    KY
# 24131                      385 AVE DOMENECH                SAN JUAN    PR
# 981                                   NYTPS  PORT JEFFERSON STATION    NY
# 15330                          56 WARREN ST                 ROXBURY    MA
# 17625                       713 HIGHLAND DR                ROCKWALL    TX
# 1883                       3420 NW 80TH TER                   MIAMI    FL
# 3046                       4320 SEMINARY RD              ALEXANDRIA    VA
# 15311               1545 68TH ST SE STE 201                KENTWOOD    MI
# 1170                       3606 SHERIDAN RD              PORTSMOUTH    OH
# 2186                271 FORT RICHARDSON AVE          GOODFELLOW AFB    TX
# 10140               211 E LOGAN ST STE B1-1                CALDWELL    ID
# 19742  5424 DISCOVERY BLVD, BLDG B, STE 203            WILLAMSBURGH    VA
# 2423                       1315 HOSPITAL DR            ST JOHNSBURY    VT
# 5626                         700 W KENT AVE                MISSOULA    MT
# 24908                        1504 TAUB LOOP                 HOUSTON    TX
# 18424                551 VETERANS UNITED DR                COLUMBIA    MO
# 21223                        438 N WHITE RD                SAN JOSE    CA
# 28734                521 BIG GRAVE CREEK RD             MOUNDSVILLE    WV
# 23931                  2579 CHIMNEY ROCK RD          HENDERSONVILLE    NC
# 6574                       5246 BRITTANY DR             BATON ROUGE    LA
# 6493                    4289 NW AMERICAN LN               LAKE CITY    FL
# 18629                900 E DIEHL RD STE 101              NAPERVILLE    IL
# 10661                       155 N FRESNO ST                  FRESNO    CA
# 27277                    7703 FLOYD CURL DR             SAN ANTONIO    TX
#
#        Zip Code                                      Clean_address   latitude  \
# 8348      89128  7670 W LAKE MEAD BLVD STE 135, LAS VEGAS, NV 8...        NaN
# 373       40205     2620 BARDSTOWN RD STE 4, LOUISVILLE, KY 40205         NaN
# 24131     91837              385 AVE DOMENECH, SAN JUAN, PR 91837         NaN
# 981       11776           NYTPS, PORT JEFFERSON STATION, NY 11776         NaN
# 15330     21193                   56 WARREN ST, ROXBURY, MA 21193         NaN
# 17625     75087               713 HIGHLAND DR, ROCKWALL, TX 75087   32.938894
# 1883      33147                 3420 NW 80TH TER, MIAMI, FL 33147   25.846977
# 3046      22304            4320 SEMINARY RD, ALEXANDRIA, VA 22304   38.822381
# 15311     49508       1545 68TH ST SE STE 201, KENTWOOD, MI 49508         NaN
# 1170      45662            3606 SHERIDAN RD, PORTSMOUTH, OH 45662   38.764090
# 2186      76908  271 FORT RICHARDSON AVE, GOODFELLOW AFB, TX 76...        NaN
# 10140     83605       211 E LOGAN ST STE B1-1, CALDWELL, ID 83605         NaN
# 19742     23188  5424 DISCOVERY BLVD, BLDG B, STE 203, WILLAMSB...        NaN
# 2423      58199          1315 HOSPITAL DR, ST JOHNSBURY, VT 58199         NaN
# 5626      59801                700 W KENT AVE, MISSOULA, MT 59801   46.851648
# 24908     77030                 1504 TAUB LOOP, HOUSTON, TX 77030   29.710611
# 18424     65201        551 VETERANS UNITED DR, COLUMBIA, MO 65201   38.900947
# 21223     95127                438 N WHITE RD, SAN JOSE, CA 95127   37.377724
# 28734     26041     521 BIG GRAVE CREEK RD, MOUNDSVILLE, WV 26041   39.904399
# 23931     28792    2579 CHIMNEY ROCK RD, HENDERSONVILLE, NC 28792   35.349055
# 6574      70808           5246 BRITTANY DR, BATON ROUGE, LA 70808   30.401480
# 6493      32055          4289 NW AMERICAN LN, LAKE CITY, FL 32055   30.185017
# 18629     60563      900 E DIEHL RD STE 101, NAPERVILLE, IL 60563         NaN
# 10661     93701                 155 N FRESNO ST, FRESNO, CA 93701   36.744186
# 27277     78229         7703 FLOYD CURL DR, SAN ANTONIO, TX 78229   29.504865
#
#         longitude
# 8348          NaN
# 373           NaN
# 24131         NaN
# 981           NaN
# 15330         NaN
# 17625  -96.468244
# 1883   -80.253593
# 3046   -77.104734
# 15311         NaN
# 1170   -82.978142
# 2186          NaN
# 10140         NaN
# 19742         NaN
# 2423          NaN
# 5626  -114.007989
# 24908  -95.393429
# 18424  -92.332186
# 21223 -121.837209
# 28734  -80.729746
# 23931  -82.432663
# 6574   -91.109294
# 6493   -82.706748
# 18629         NaN
# 10661 -119.781671
# 27277  -98.576128

# %% [markdown]
# <font color=#1DA1F2>
#
# **OpenStreetMap-took 38 min to Geocode 1000 addresses**
